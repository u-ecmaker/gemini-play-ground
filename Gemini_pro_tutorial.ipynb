# %% [markdown]
# <a href="https://colab.research.google.com/github/u-ecmaker/gemini-play-ground/blob/main/Gemini_pro_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %% [markdown]
# # API KEYの設定など

# %%
import pathlib
import textwrap

import google.generativeai as genai

# Used to securely store your API key
from google.colab import userdata

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
import getpass
apikey = getpass.getpass(prompt = 'GeminiのAPIキーを入力してください') # https://makersuite.google.com/app/apikey
genai.configure(api_key=apikey)
# Out:
# GeminiのAPIキーを入力してください··········

# %% [markdown]
# # 言語生成モデル

# %%
model = genai.GenerativeModel('gemini-exp-1206')

# %%
response = model.generate_content("Pythonの勉強方法を教えてください",
                                  generation_config=genai.types.GenerationConfig(
                                      candidate_count=1, # 現在は1個まで
                                      temperature=0.9
                                  ))
to_markdown(response.text)
# Out:
# > Pythonの勉強方法はいくつかありますが、ご自身の学習スタイルや目標に合わせて選ぶことが大切です。ここでは、一般的な方法をいくつか紹介します。
# >
# > **1. オンライン学習プラットフォームの利用**
# >
# > * **メリット:**
# >     * 自分のペースで学習できる
# >     * 豊富なコースから選べる
# >     * 比較的安価
# >     * わからないことを質問できるコミュニティがある場合も
# > * **デメリット:**
# >     * モチベーション維持が難しい場合がある
# >     * 実践的な経験を積みにくい場合がある
# > * **おすすめプラットフォーム:**
# >     * **Progate:** 初心者向けのわかりやすい説明と、実際にコードを書いて学べる演習が豊富。基本は無料。
# >     * **ドットインストール:** 3分動画で、様々なプログラミング言語や技術を学べる。基本は無料。
# >     * **Udemy:** 有料だが、幅広い分野のコースが揃っており、専門的な知識を深められる。
# >     * **Codecademy:** インタラクティブなレッスンで、手を動かしながら学べる。
# >     * **Coursera:** 世界の有名大学の講座を受講できる。
# >     * **edX:** ハーバード大学やMITなどの有名大学が提供するオンラインコース。
# >
# > **2. 書籍での学習**
# >
# > * **メリット:**
# >     * 体系的に学べる
# >     * 手元に置いて、いつでも参照できる
# >     * 自分のペースでじっくり学習できる
# > * **デメリット:**
# >     * 最新情報に対応していない場合がある
# >     * わからないことをすぐに質問できない
# > * **おすすめ書籍:**
# >     * **入門 Python 3:** Pythonの基礎から応用まで、幅広く網羅された定番の入門書。
# >     * **スラスラわかるPython:**  イラストや図解が豊富で、初心者にもわかりやすい。
# >     * **みんなのPython 第4版:**  基礎から実践的な内容まで、幅広いトピックをカバー。
# >     * **Pythonスタートブック:** プログラミング自体が初めての人にも優しい、丁寧な解説。
# >     * **Pythonエンジニア ファーストブック:** Pythonの基本からWeb開発、データ分析、機械学習などの応用まで、エンジニアとして必要な知識を学べる。
# >
# > **3. チュートリアルサイトの利用**
# >
# > * **メリット:**
# >     * 無料で学べる
# >     * 具体的な課題を解決しながら学べる
# >     * 目的別の学習がしやすい
# > * **デメリット:**
# >     * 体系的な学習には向かない場合がある
# >     * 情報が古い場合がある
# > * **おすすめサイト:**
# >     * **Python公式チュートリアル:** Pythonの公式ドキュメントの一部で、基礎から応用までをカバー。
# >     * **Python Japan:** 日本のPythonコミュニティによる情報サイト。様々なチュートリアルが掲載されている。
# >     * **CheckiO:** ゲーム形式でPythonを学べる。
# >     * **Python-izm:** 初心者から上級者まで、幅広いレベルのチュートリアルを提供。
# >
# > **4. プログラミングスクールの利用**
# >
# > * **メリット:**
# >     * 経験豊富な講師から直接指導を受けられる
# >     * カリキュラムが組まれているため、体系的に学べる
# >     * 同じ目標を持つ仲間と出会える
# >     * 就職・転職支援が受けられる場合も
# > * **デメリット:**
# >     * 他の方法に比べて費用が高い
# >     * 時間的な制約がある
# > * **おすすめスクール:**
# >     * **TechAcademy [テックアカデミー]:** オンライン完結型のプログラミングスクール。様々なコースがあり、Pythonも学べる。
# >     * **侍エンジニア:** マンツーマン指導が特徴のプログラミングスクール。
# >     * **CodeCamp:** オンライン完結型のプログラミングスクール。
# >     * **DMM WEBCAMP:** 転職・就職支援が充実したプログラミングスクール。
# >
# > **5. 実際にコードを書いてみる**
# >
# > * **最も重要な学習方法です。**
# > * **小さなプログラムから始めて、徐々に複雑なものに挑戦していくのがおすすめです。**
# > * **以下のような方法で実践的な経験を積むことができます。**
# >     * **学習サイトや書籍の練習問題を解く**
# >     * **簡単なゲームやツールを作ってみる**
# >     * **オープンソースプロジェクトに参加する**
# >     * **Kaggleなどのデータ分析コンペティションに参加する**
# >     * **AtCoderなどの競技プログラミングに挑戦する**
# >
# > **学習の進め方**
# >
# > 1. **目標を設定する:** 何のためにPythonを学ぶのか、どのようなことができるようになりたいのかを明確にしましょう。
# > 2. **基礎を固める:** 基本的な文法やデータ構造を理解することが重要です。
# > 3. **実践的なプロジェクトに取り組む:** 学んだことを活かして、実際にプログラムを作ってみましょう。
# > 4. **継続的に学習する:** プログラミングは継続的な学習が重要です。毎日少しずつでもコードを書くようにしましょう。
# > 5. **コミュニティに参加する:** 他の学習者と交流したり、質問したりすることで、モチベーションを維持し、効率的に学習できます。
# >
# > **学習を続けるためのヒント**
# >
# > * **小さな目標を設定する:** いきなり大きな目標を設定するのではなく、小さな目標を立てて、達成感を得られるようにしましょう。
# > * **学習仲間を見つける:** 一緒に学習する仲間がいると、モチベーションを維持しやすくなります。
# > * **楽しむことを忘れない:** プログラミングは楽しいものです。楽しみながら学習を続けましょう。
# > * **エラーを恐れない:** プログラミングではエラーはつきものです。エラーを恐れずに、積極的に試行錯誤しましょう。
# > * **行き詰まったら、休憩する:** 行き詰まったら、無理に続けずに、一旦休憩しましょう。リフレッシュすることで、新たな視点が得られることがあります。
# >
# > Pythonは、初心者にも学びやすく、幅広い用途に使えるプログラミング言語です。上記の学習方法を参考に、自分に合った方法で学習を進めてみてください。応援しています！

# %%
response.candidates
# Out:
# [content {
#   parts {
#     text: "1. Python\343\201\256\345\237\272\347\244\216\343\202\222\347\220\206\350\247\243\343\201\231\343\202\213\343\200\202\345\244\211\346\225\260\343\200\201\351\226\242\346\225\260\343\200\201\345\210\266\345\276\241\343\203\225\343\203\255\343\203\274\343\200\201\343\203\207\343\203\274\343\202\277\346\247\213\351\200\240\343\200\201\343\202\252\343\203\226\343\202\270\343\202\247\343\202\257\343\203\210\346\214\207\345\220\221\343\203\227\343\203\255\343\202\260\343\203\251\343\203\237\343\203
343\201\253\351\226\242\343\201\231\343\202\213\346\233\270\347\261\215\343\202\204\350\250\230\344\272\213\343\201\257\343\201\237\343\201\217\343\201\225\343\202\223\343\201\202\343\202\212\343\201\276\343\201\231\343\201\256\343\201\247\343\200\201\343\201\235\343\202\214\343\202\211\343\202\222\346\264\273\347\224\250\343\201\227\343\201\246\350\207\252\345\210\206\343\201\256\343\202\271\343\202\255\343\203\25 ...
#   }
#   role: "model"
# }
# finish_reason: STOP
# index: 0
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }
# ]

# %% [markdown]
# # 画像生成モデル

# %%
import PIL.Image

img = PIL.Image.open('hoge.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=430x430>

# %%
model = genai.GenerativeModel('gemini-exp-1206')

# %%
response = model.generate_content(["この画像を基に歌を作ってください", img], stream=True)
response.resolve()
to_markdown(response.text)
# Out:
# > もちろん！画像をもとに作った歌です。
# >
# > ほっげ ほっげ ほっげ
# > ほっげ ほっげ ほっげ
# > ほっげ ほっげ ほっげ
# >
# > ほっげのお魚 美味しいね
# > ほっげのお魚 みんなで食べよう
# > ほっげのお魚 栄養満点
# > ほっげのお魚 元気いっぱい
# >
# > ほっげ ほっげ ほっげ
# > ほっげ ほっげ ほっげ
# > ほっげ ほっげ ほっげ
# >
# > ほっげのお魚 焼いても美味しい
# > ほっげのお魚 煮ても美味しい
# > ほっげのお魚 揚げても美味しい
# > ほっげのお魚 何でも美味しい
# >
# > ほっげ ほっげ ほっげ
# > ほっげ ほっげ ほっげ
# > ほっげ ほっげ ほっげ
# >
# > ほっげのお魚 みんな大好き
# > ほっげのお魚 いつもありがとう
# > ほっげのお魚 これからもよろしく
# > ほっげのお魚 大好きだよ
# >
# > ほっげ ほっげ ほっげ
# > ほっげ ほっげ ほっげ
# > ほっげ ほっげ ほっげ

# %% [markdown]
# # Geminiのチャットを使ってみる

# %%
model = genai.GenerativeModel('gemini-exp-1206')

# %%
from IPython.display import HTML, display

def display_message(message, background_color="#DDDDDD"):
    display(HTML(f"<div style='background-color: {background_color}; padding: 10px;'>{message}</div>"))

chat = model.start_chat(history=[])
while True:
    user_message = input("You: ")
    response = chat.send_message(user_message)
    gemini_message = chat.history[-1].parts[0].text
    display_message(f'Gemini: {gemini_message}', background_color="#AAF0D1")
# Out:
# You: こんにちは
# <div style='background-color: #AAF0D1; padding: 10px;'>Gemini: こんにちは。何ができるかお手伝いしましょうか？</div>
# You: 日本の首都はどこですか？
# <div style='background-color: #AAF0D1; padding: 10px;'>Gemini: 日本の首都は東京です。</div>
# You: OpenAIについてどう思いますか？
# ---------------------------------------------------------------------------
# StopCandidateException                    Traceback (most recent call last)
# <ipython-input-13-7c5787594223> in <cell line: 7>()
#       7 while True:
#       8     user_message = input("You: ")
# ----> 9     response = chat.send_message(user_message)
#      10     gemini_message = chat.history[-1].parts[0].text
#      11     display_message(f'Gemini: {gemini_message}', background_color="#AAF0D1")
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in send_message(self, content, generation_config, safety_settings, stream, **kwargs)
#     373                 glm.Candidate.FinishReason.MAX_TOKENS,
#     374             ):
# --> 375                 raise generation_types.StopCandidateException(response.candidates[0])
#     376
#     377         self._last_sent = content
#
# StopCandidateException: finish_reason: OTHER
# index: 0
